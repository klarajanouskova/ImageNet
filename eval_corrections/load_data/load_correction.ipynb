# %% [markdown]
# ### Loading any dataset correction into a DF by simply changing the import class.

# %%
from validation_correction.imagenet_label_errors.label_errors import LabelErrors as Dataset

# %%
dataset = Dataset()
dataset.set_entries()

# %%
df = dataset.entries_to_dataframe()

# %%
df
# Out:
#                                 id category  original_label proposed_labels  \
# 0     ILSVRC2012_val_00000293.JPEG        A               0               0
# 1     ILSVRC2012_val_00030740.JPEG        A               0               0
# 2     ILSVRC2012_val_00031094.JPEG        A               0               0
# 3     ILSVRC2012_val_00037383.JPEG        X               0
# 4     ILSVRC2012_val_00000236.JPEG        A               1               1
# ...                            ...      ...             ...             ...
# 5435  ILSVRC2012_val_00020175.JPEG        A             999             999
# 5436  ILSVRC2012_val_00024774.JPEG        M             999        999, 861
# 5437  ILSVRC2012_val_00038640.JPEG        X             999
# 5438  ILSVRC2012_val_00042270.JPEG        A             999             999
# 5439  ILSVRC2012_val_00047144.JPEG        B             999             333
#
#       manually_validated cl_label  \
# 0                   True       48
# ...
